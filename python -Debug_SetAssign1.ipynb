# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
#print(b + a)
print(a*b)

#we cannot add a string with a number datatype , so only a multiplication between string and int is allowed
# Out:
# 5555555555

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    return a + b

#no call to function

# %%
add_numbers(9,10)
# Out:
# 19

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 1
print(x)

#division by zero error is thrown , as the variable does not support such a value storage. We can even divide the number by any other integer value.
# Out:
# 5.0

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
print("Name: ", name," Age: ",  age)
# Out:
# Name:  Alice  Age:  25

# %%
#8.Find the error
for i in range(10, 1,-1):
    print(i)
#range generally progresses forward based on the step count, since its -1 it wont move forward. So we can change it to range(10,1,-1)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x == 5:
    print("x is 5")
else:
    print("x is ",x)

    #there is no else statement to catch any other number, so the if loop will never be executed
# Out:
# x is  10

# %%
#10. Identify the error in the following function definition:

def greet(name):
    print("Hello, " + name)

# there is no call to function

# %%
greet("Sunanda")
# Out:
# Hello, Sunanda
