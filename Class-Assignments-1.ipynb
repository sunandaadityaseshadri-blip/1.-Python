# %%
from MultiFunctions import SubfieldsInAI

# %%
SubFieldList = ["Machine Learning", "Neural Networks","Vision", "Robotics", "Speech Processing", "Natural Language Processing"]

print("Sub-fields in AI are :")
SubfieldsInAI.Subfields(SubFieldList)
# Out:
# Sub-fields in AI are :
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
from MultiFunctions import OddEven

# %%
numb = int(input("Enter a number: "))
OddEven.OddEven(numb)
# Out:
# Enter a number:  2
# 2 is Even number

# %%
from MultiFunctions import ElegiblityForMarriage

# %%
Gender = input("Your Gender: ")
Age = int(input("Your Age: "))
ElegiblityForMarriage.Elegible(Gender, Age)
# Out:
# Your Gender:  male
# Your Age:  32
# Eligible

# %%
from MultiFunctions import FindPercent

# %%
eng= int(input("Subject1= "))
mat= int(input("Subject2= "))
phy= int(input("Subject3= "))
che= int(input("Subject4= "))
bio= int(input("Subject5= "))
tuple1, tuple2 = FindPercent.percentage(eng,mat,phy,che,bio)
print("Total :",tuple1)
print("Percentage :",tuple2)
# Out:
# Subject1=  89
# Subject2=  13
# Subject3=  23
# Subject4=  454
# Subject5=  55
# Total : 634
# Percentage : 126.8

# %%
from MultiFunctions import triangle

# %%
triangle.triangle(32,34,2,4,4)
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:  10
