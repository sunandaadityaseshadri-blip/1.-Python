# %%
print("Sunanda")
# Out:
# Sunanda

# %%
print("dU1934?><)(&)(*&^")
# Out:
# dU1934?><)(&)(*&^

# %%
Print("sunanda")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print("sunanda")
#
# NameError: name 'Print' is not defined

# %%
print("NameError generally comes for two reason. first reason is spelling mistake. second reason will be revealed later")
# Out:
# NameError generally comes for two reason. first reason is spelling mistake. second reason will be revealed later

# %%
print("print considers the text within the double quotes as a string")
# Out:
# print considers the text within the double quotes as a string
