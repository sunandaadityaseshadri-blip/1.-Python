# %%
num1=10
num2= 30
add = num1+num2

# %%
print(add)
# Out:
# 40

# %%
print("variables look black in colour, while reserved keywords are in green")
# Out:
# variables look black in colour, while reserved keywords are in green

# %%
print("ensure variable names are sensible. Dnt create random values for variables. Variable names cannot contain spaces.you cud use underscore. Use camelcase. also variables cannot start with a number")
# Out:
# ensure variable names are sensible. Dnt create random values for variables. Variable names cannot contain spaces.you cud use underscore. Use camelcase. also variables cannot start with a number

# %%
print("The addition of two numbers")
print("The number1 is: ",num1)
print("The number2 is: ",num2)
print("Answer is: ",add)
print("If not we try subtraction like this -> ",num2-num1)
print("can I override num1?")
num1=20
print("now num1+num2 is : ",num1+num2)
# Out:
# The addition of two numbers
# The number1 is:  10
# The number2 is:  30
# Answer is:  40
# If not we try subtraction like this ->  20
# can I override num1?
# now num1+num2 is :  50

# %%
num3=input("Enter num3 : ")
# Out:
# Enter num3 :  40

# %%
num4 = input("Enter num4 : ")
# Out:
# Enter num4 :  30

# %%
add = num3+num4
print(add)
# Out:
# 4030

# %%
print("as you cud see, the above input were considered as string, so ensure that you include the type prior to Input")
# Out:
# as you cud see, the above input were considered as string, so ensure that you include the type prior to Input

# %%
num3= int(input("Enter num3: "))
# Out:
# Enter num3:  100

# %%
num4 = int(input("Enter num4: "))
# Out:
# Enter num4:  50

# %%
add=num3+num4

# %%
print(add)
print(mul)
# Out:
# 150
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 print(add)
# ----> 2 print(mul)
#
# NameError: name 'mul' is not defined

# %%
print("the above msg says Mul as a var is not defined, secondly even if you have defined and did not execute, you may get this error")
# Out:
# the above msg says Mul as a var is not defined, secondly even if you have defined and did not execute, you may get this error

# %%
print("this box is called as a cell. After every cell gets executed (shift+enter), the cell gets a number on the left side. As you can see this cell number going to be 27. if you plan to get a user input and after the system attempted to get the value from you and you typed the value and pressed enter, it accepts; otherwise if you press run command again it may change this cell number as asterix. you may probably need to choose kernal > restart and clear output or press stop icon seen above")
# Out:
# this box is called as a cell. After every cell gets executed (shift+enter), the cell gets a number on the left side. As you can see this cell number going to be 27. if you plan to get a user input and after the system attempted to get the value from you and you typed the value and pressed enter, it accepts; otherwise if you press run command again it may change this cell number as asterix. you may probably need to choose kernal > restart and clear output or press stop icon seen above
