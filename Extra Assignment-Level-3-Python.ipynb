# %%
#method 1 - I leave the else condition without handling
Value = int(input("value"))
if(Value==10):
    print("correct")
# Out:
# value 20

# %%
#method 2 - where I handle the else clause
Value = int(input("value"))
if(Value==10):
    print("correct") 
else:
    print("incorrect")
# Out:
# value 10
# correct

# %%
Pwd = input("Enter the password :")
if(Pwd == "HOPE@123"):
    print("your password is correct")
else:
    print("incorrect password")
# Out:
# Enter the password : erefgr
# incorrect

# %%
Age = int(input("age : "))
if(Age < 15):
    print("child")
elif(Age <= 40):
    print("adult")
elif(Age < 60):
    print("citizen")
else:
    print("senior citizen")
# Out:
# age :  60
# senior citizen

# %%
Num3 = int(input("Enter a number :"))
if(Num3<0):
    print(Num3, "is a negative number")
elif(Num3>0):
    print(Num3, "is a positive number")
else:
    print(Num3, "is a neutral number")
# Out:
# Enter a number : 0
# 0 is a neutral number

# %%
Num4 = int(input("Enter a number to check :")) 
if(Num4%5==0): 
    print(Num4, "is divisible by 5") 
else: 
    print(Num4, "is not divisible by 5")
# Out:
# Enter a number to check : 78786870
# 78786870 is divisible by 5
